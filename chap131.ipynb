# %% [markdown]
# TrackbarastheColorPalette

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('tkakr.jpg')

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
k = cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
px = img[100,100]
print (px)
# Out:
# [ 66 137 217]

# %%
blue = img[100,100,0]
print (blue)
# Out:
# 66

# %%
img[20:40,30:40,2] = 255

cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
k = cv2.waitKey(0)
cv2.destroyAllWindows()
