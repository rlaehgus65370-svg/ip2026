# %% [markdown]
# Control Flow

# %%
x = 3
while x < 5:
    
    print (x, "still in the loop")
x = x + 1

# %%
for x in range(5):
    print (x)

# %%
for (x, y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print  (y)
