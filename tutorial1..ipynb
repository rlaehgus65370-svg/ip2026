# %%
tu = (23, 'abc', 4.56, (2,3), 'def')
print(tu)

li = ["abc", 34, 4.34, 23]
print(li)

st = "Hello World"
print(st)
st = 'Hello World'
print(st)
st = """This is a multi-line
string that uses triple quotes."""
print(st)

tu = (23, 'abc', 4.56, (2,3), 'def')
print(tu[1]) # Second item in the tuple.

li = ["abc", 34, 4.34, 23]
print(li[1]) # Second item in the list.

st = "Hello World"
print(st[1]) # Second character in string.

t = (23, 'abc', 4.56, (2,3), 'def')
print(t[-3])
print(t[1:4])
print(t[1:-1])
print(t[1:-1:2])
print(t[:2])
print(t[2:])
print(t[:])

t = [1, 2, 4, 5]
3 in t
4 in t
4 not in t

a = 'abcde'
'c' in a
'cd' in a
'ac' in a
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')
# ['abc', 34, 4.34, 23]
# Hello World
# Hello World
# This is a multi-line
# string that uses triple quotes.
# abc
# 34
# e
# 4.56
# ('abc', 4.56, (2, 3))
# ('abc', 4.56, (2, 3))
# ('abc', (2, 3))
# (23, 'abc')
# (4.56, (2, 3), 'def')
# (23, 'abc', 4.56, (2, 3), 'def')
# False
