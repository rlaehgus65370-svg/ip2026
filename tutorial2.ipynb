# %%
li = ['abc', 23, 4.34, 23]
li[1] = 45 
print(li)

# %%
t = (23, 'abc', 4.56, (2,3), 'def')
t[2] = 3.14

# %%
li = [1, 11, 3, 4, 5]
li.append('a')
print(li)

li = [1, 11, 3, 4, 5]
li.insert(2, 'i')
print(li)

li = [1, 11, 3, 4, 5]
li.extend([9, 8, 7])
print(li)

li = [1, 11, 3, 4, 5]
li.append([10, 11, 12])
print(li)

# %%
li = ['a', 'b', 'c', 'b']
print(li.index('b'))

li = ['a', 'b', 'c', 'b']
print(li.count('b'))

li = ['a', 'b', 'c', 'b']
li.remove('b')
print(li

# %%
li = [5, 2, 6, 8]
li.reverse()
print(li)

li = [5, 2, 6, 8]
li.sort()
print(li)
